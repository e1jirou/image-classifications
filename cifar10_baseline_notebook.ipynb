# %% [markdown]
# # CIFAR-10 \~\~\~Baseline Version\~\~\~
# This is a notebook which classified CIFAR-10 by using google colaboratory.<br>
# Test accuracy was 91.41 %.<br>
# ## Summary
# * Accelerator: TPU
# * Data Augmentation: Horizontal Flip, Random Crop (Parallel Translation)
# * Model: (Conv-BN-Conv-BN-Maxpool)x2 - Conv - BN - Conv - BN - GAP - Dropout - Dense - Dropout - Dense
# * Training: epochs<=100, batch_size=64, optimizer=Adam, Reduce Learning Rate

# %% [markdown]
# Mount My Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

work_dir = "/content/drive/My Drive/Colab Notebooks/cifar10/"
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import modules

# %%
# !pip install visualkeras
from visualkeras import layered_view
# Out:
# Collecting visualkeras
#   Downloading https://files.pythonhosted.org/packages/3c/7d/86ba86f710378e753ed690048710bf917b9121b7c6c5f5b07ec5323c4adc/visualkeras-0.0.1-py3-none-any.whl
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.6/dist-packages (from visualkeras) (7.0.0)
# Installing collected packages: visualkeras
# Successfully installed visualkeras-0.0.1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from collections import Counter, defaultdict

import tensorflow as tf
from tensorflow import keras
from keras.layers import *
from keras.models import Model, load_model
from keras.optimizers import Adam
from keras.utils import plot_model
#from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.losses import categorical_crossentropy

print('tensorflow varsion:', tf.__version__)
print(tf.test.gpu_device_name())
# Out:
# tensorflow varsion: 2.4.1

# %% [markdown]
# Prepare for using TPU

# %%
tf.keras.backend.clear_session()

resolver = tf.distribute.cluster_resolver.TPUClusterResolver('grpc://' + os.environ['COLAB_TPU_ADDR'])
tf.config.experimental_connect_to_cluster(resolver)

# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))

strategy = tf.distribute.experimental.TPUStrategy(resolver)
# Out:
# INFO:tensorflow:Initializing the TPU system: grpc://10.106.48.234:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.106.48.234:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU')]
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %% [markdown]
# # Load and check data

# %% [markdown]
# Load data

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
len(classes)
# Out:
# 10

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# Check data

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
np.min(X_train), np.max(X_train), np.min(X_test), np.max(X_test)
# Out:
# (0, 255, 0, 255)

# %%
def plot_count(y, classes=None, title='y count'):
    plt.figure(figsize=(10,5))
    counter_y = [(key, value) for key, value in Counter(y).items()]
    counter_y.sort(key=lambda x: x[0])
    if classes is None:
        classes = [key for key, value in counter_y]
    values = [value for key, value in counter_y]
    plt.bar(classes, values)
    plt.xlabel('classes')
    plt.ylabel('count')
    plt.title(title)
    plt.show()

y_train = np.ravel(y_train)
y_test = np.ravel(y_test)

plot_count(y_train, classes, title='y_train count')
plot_count(y_test, classes, title='y_test count')

# %%
# show 10 images
def show_images(X, y_true=np.zeros(10), y_pred=None, classes=defaultdict(str)):
    plt.figure(figsize=(10,5))
    for i in range(min(10, X.shape[0], y_true.shape[0])):
        plt.subplot(2,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)

        # plot image
        try:
            plt.imshow(X[i], cmap=plt.cm.binary)
        except:
            plt.imshow(np.reshape(X[i],(X.shape[1],X.shape[2])), cmap=plt.cm.binary)

        # show y_true
        label = ''
        if len(y_true.shape) == 1:
            label += classes[y_true[i]]
        elif len(y_true.shape) == 2:
            label_rate = np.argsort(y_true[i])[::-1]
            if y_true[i][label_rate[0]] > 0.99:
                label = classes[label_rate[0]]
            else:
                label += classes[label_rate[0]] + ': ' + f'{y_true[i][label_rate[0]]:.2f}'
                label += '\n' + classes[label_rate[1]]+': ' + f'{y_true[i][label_rate[1]]:.2f}'
                
        # show y_pred
        if y_pred is None:
            plt.xlabel(label)
            continue

        plt.ylabel('Answer: ' + label)
        label = 'Prediction\n'
        if len(y_pred.shape) == 1:
            label += classes[y_pred[i]]
        elif len(y_pred.shape) == 2:
            label_rate = np.argsort(y_pred[i])[::-1]
            label += classes[label_rate[0]] + ': ' + f'{y_pred[i][label_rate[0]]:.2f}'
            if y_pred[i][label_rate[1]] > 0.01:
                label += '\n' + classes[label_rate[1]]+': ' + f'{y_pred[i][label_rate[1]]:.2f}'
        plt.xlabel(label)

    plt.show()

# %%
show_images(X_train, y_train, classes=classes)

# %% [markdown]
# # Preprocess data

# %% [markdown]
# Normalize images

# %%
X_train = X_train / 255
X_test = X_test / 255
np.min(X_train), np.max(X_train), np.min(X_test), np.max(X_test)
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# Change shapes

# %%
y_train = keras.utils.to_categorical(y_train, len(classes))
y_test = keras.utils.to_categorical(y_test, len(classes))

# %% [markdown]
# train_test_split

# %%
validation_seed = 0
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train, y_train, test_size=0.2, random_state=validation_seed)

print(X_train.shape, X_valid.shape, X_test.shape)
print(y_train.shape, y_valid.shape, y_test.shape)
# Out:
# (40000, 32, 32, 3) (10000, 32, 32, 3) (10000, 32, 32, 3)
# (40000, 10) (10000, 10) (10000, 10)

# %% [markdown]
# # Augment data

# %%
batch_size = 64
steps_per_epoch = X_train.shape[0] // batch_size
epochs = 100

# %%
def data_augmentation(img):
    img = tf.image.random_flip_left_right(img)
    img = tf.pad(img, tf.constant([[4,4],[4,4],[0,0]]), 'SYMMETRIC')
    img = tf.image.random_crop(img, size=X_train[0].shape)
    return img

# %%
print('Before augmentation')
show_images(X_train[:10], y_train[:10], classes=classes)
# Out:
# Before augmentation

# %%
print('After augmentation')
X_aug = np.array([data_augmentation(img) for img in X_train[:10]])
show_images(X_aug, y_train[:10], classes=classes)
# Out:
# After augmentation

# %%
trainset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
trainset = trainset.map(lambda img, label:(data_augmentation(img), label))
trainset = trainset.shuffle(buffer_size=1024).repeat().batch(64)

# %%
print('Data augmentation uses this time per 1 epoch.')

def measure_time(datagen_flow, steps_per_epoch):
    cnt = 0
    for X_aug, y_aug in datagen_flow:
        cnt += 1
        if cnt == steps_per_epoch:
            break

# %timeit -r 5 measure_time(trainset, steps_per_epoch)
# Out:
# Data augmentation uses this time per 1 epoch.
# 1 loop, best of 5: 7.06 s per loop

# %% [markdown]
# # Create model

# %%
def create_model(input_shape, num_classes):
    filters = 64
    repeat = 3

    inputs = Input(shape=input_shape)
    x = inputs
    
    for i in range(repeat):
        x = Conv2D(filters, (3,3), activation='relu', padding='same')(x)
        x = BatchNormalization()(x)
        x = Conv2D(filters, (3,3), activation='relu', padding='same')(x)
        x = BatchNormalization()(x)
        if i < repeat - 1:
            x = MaxPooling2D(pool_size=(2,2))(x)
            filters *= 2

    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.25)(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=x)
    return model

model = create_model(input_shape=X_train[0].shape, num_classes=len(classes))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              263168
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 1,422,410
# Trainable params: 1,420,618
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True, dpi=48)

# %%
layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=834x171 at 0x7F4F1D8A90F0>

# %% [markdown]
# # Train model

# %%
weights_file_name = "baseline_weights(seed={}).hdf5".format(validation_seed)
model_file_name = "baseline_model(seed={}).h5".format(validation_seed)

# %%
# %%time

with strategy.scope():
    model = create_model(input_shape=X_train[0].shape, num_classes=len(classes))
    model.compile(loss="categorical_crossentropy", optimizer=Adam(), metrics=["accuracy"])

save_weights = ModelCheckpoint(filepath=os.path.join(work_dir, weights_file_name),
                                verbose=0, save_best_only=True, save_weights_only=True,
                                monitor='val_loss', mode='min')

early_stop = EarlyStopping(monitor='val_loss', mode='min',
                                patience=10, restore_best_weights=True, verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', mode='min',
                                factor=0.5, patience=5, verbose=1)

history = model.fit(trainset, validation_data=(X_valid, y_valid),
                                epochs=epochs, steps_per_epoch=steps_per_epoch,
                                verbose=2, callbacks=[save_weights, early_stop, reduce_lr])

model.save(os.path.join(work_dir, model_file_name))
# Out:
# Epoch 1/100
# 625/625 - 19s - loss: 1.4931 - accuracy: 0.4653 - val_loss: 1.1574 - val_accuracy: 0.5847
# Epoch 2/100
# 625/625 - 8s - loss: 1.0876 - accuracy: 0.6201 - val_loss: 1.3973 - val_accuracy: 0.5617
# Epoch 3/100
# 625/625 - 8s - loss: 0.9107 - accuracy: 0.6859 - val_loss: 1.0645 - val_accuracy: 0.6514
# Epoch 4/100
# 625/625 - 8s - loss: 0.8030 - accuracy: 0.7248 - val_loss: 0.6154 - val_accuracy: 0.7866
# Epoch 5/100
# 625/625 - 8s - loss: 0.7196 - accuracy: 0.7566 - val_loss: 0.6924 - val_accuracy: 0.7641
# Epoch 6/100
# 625/625 - 8s - loss: 0.6630 - accuracy: 0.7764 - val_loss: 0.6891 - val_accuracy: 0.7677
# Epoch 7/100
# 625/625 - 8s - loss: 0.6184 - accuracy: 0.7918 - val_loss: 0.6105 - val_accuracy: 0.7944
# Epoch 8/100
# 625/625 - 8s - loss: 0.5770 - accuracy: 0.8046 - val_loss: 0.5185 - val_accuracy: 0.8309
# Epoch 9/100
# 625/625 - 8s - loss: 0.5529 - accuracy: 0.8143 - val_loss: 0.6749 - val_accuracy: 0.7782
# Epoch 10/100
# 625/625 - 8s - loss: 0.5199 - accuracy: 0.8267 - val_loss: 0.5085 - val_accuracy: 0.8335
# Epoch 11/100
# 625/625 - 8s - loss: 0.4957 - accuracy: 0.8321 - val_loss: 0.4574 - val_accuracy: 0.8457
# Epoch 12/100
# 625/625 - 8s - loss: 0.4840 - accuracy: 0.8361 - val_loss: 0.4138 - val_accuracy: 0.8593
# Epoch 13/100
# 625/625 - 8s - loss: 0.4588 - accuracy: 0.8442 - val_loss: 0.5183 - val_accuracy: 0.8353
# Epoch 14/100
# 625/625 - 8s - loss: 0.4475 - accuracy: 0.8498 - val_loss: 0.4824 - val_accuracy: 0.8442
# Epoch 15/100
# 625/625 - 8s - loss: 0.4285 - accuracy: 0.8552 - val_loss: 0.4106 - val_accuracy: 0.8662
# Epoch 16/100
# 625/625 - 8s - loss: 0.4150 - accuracy: 0.8588 - val_loss: 0.4596 - val_accuracy: 0.8533
# Epoch 17/100
# 625/625 - 8s - loss: 0.3982 - accuracy: 0.8674 - val_loss: 0.4384 - val_accuracy: 0.8582
# Epoch 18/100
# 625/625 - 8s - loss: 0.3896 - accuracy: 0.8697 - val_loss: 0.4527 - val_accuracy: 0.8542
# Epoch 19/100
# 625/625 - 8s - loss: 0.3806 - accuracy: 0.8726 - val_loss: 0.4377 - val_accuracy: 0.8599
# Epoch 20/100
# 625/625 - 8s - loss: 0.3688 - accuracy: 0.8766 - val_loss: 0.6127 - val_accuracy: 0.8236
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 21/100
# 625/625 - 8s - loss: 0.3114 - accuracy: 0.8935 - val_loss: 0.3238 - val_accuracy: 0.8933
# Epoch 22/100
# 625/625 - 8s - loss: 0.2911 - accuracy: 0.9002 - val_loss: 0.3587 - val_accuracy: 0.8851
# Epoch 23/100
# 625/625 - 8s - loss: 0.2785 - accuracy: 0.9053 - val_loss: 0.3480 - val_accuracy: 0.8901
# Epoch 24/100
# 625/625 - 8s - loss: 0.2692 - accuracy: 0.9101 - val_loss: 0.3053 - val_accuracy: 0.8972
# Epoch 25/100
# 625/625 - 8s - loss: 0.2652 - accuracy: 0.9096 - val_loss: 0.3339 - val_accuracy: 0.8918
# Epoch 26/100
# 625/625 - 8s - loss: 0.2558 - accuracy: 0.9127 - val_loss: 0.3147 - val_accuracy: 0.8984
# Epoch 27/100
# 625/625 - 8s - loss: 0.2454 - accuracy: 0.9166 - val_loss: 0.3179 - val_accuracy: 0.8978
# Epoch 28/100
# 625/625 - 8s - loss: 0.2462 - accuracy: 0.9160 - val_loss: 0.3011 - val_accuracy: 0.9014
# Epoch 29/100
# 625/625 - 8s - loss: 0.2370 - accuracy: 0.9204 - val_loss: 0.3060 - val_accuracy: 0.9017
# Epoch 30/100
# 625/625 - 8s - loss: 0.2272 - accuracy: 0.9230 - val_loss: 0.3260 - val_accuracy: 0.8985
# Epoch 31/100
# 625/625 - 8s - loss: 0.2296 - accuracy: 0.9206 - val_loss: 0.3318 - val_accuracy: 0.8975
# Epoch 32/100
# 625/625 - 8s - loss: 0.2219 - accuracy: 0.9238 - val_loss: 0.3189 - val_accuracy: 0.9004
# Epoch 33/100
# 625/625 - 8s - loss: 0.2166 - accuracy: 0.9263 - val_loss: 0.3314 - val_accuracy: 0.8973
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 34/100
# 625/625 - 8s - loss: 0.1973 - accuracy: 0.9326 - val_loss: 0.2928 - val_accuracy: 0.9114
# Epoch 35/100
# 625/625 - 8s - loss: 0.1828 - accuracy: 0.9369 - val_loss: 0.2994 - val_accuracy: 0.9085
# Epoch 36/100
# 625/625 - 8s - loss: 0.1819 - accuracy: 0.9385 - val_loss: 0.3073 - val_accuracy: 0.9076
# Epoch 37/100
# 625/625 - 8s - loss: 0.1699 - accuracy: 0.9419 - val_loss: 0.3042 - val_accuracy: 0.9103
# Epoch 38/100
# 625/625 - 8s - loss: 0.1753 - accuracy: 0.9398 - val_loss: 0.3081 - val_accuracy: 0.9083
# Epoch 39/100
# 625/625 - 8s - loss: 0.1705 - accuracy: 0.9414 - val_loss: 0.3025 - val_accuracy: 0.9095
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 40/100
# 625/625 - 8s - loss: 0.1587 - accuracy: 0.9460 - val_loss: 0.2839 - val_accuracy: 0.9165
# Epoch 41/100
# 625/625 - 8s - loss: 0.1521 - accuracy: 0.9483 - val_loss: 0.2906 - val_accuracy: 0.9157
# Epoch 42/100
# 625/625 - 8s - loss: 0.1466 - accuracy: 0.9488 - val_loss: 0.2866 - val_accuracy: 0.9146
# Epoch 43/100
# 625/625 - 8s - loss: 0.1429 - accuracy: 0.9515 - val_loss: 0.2913 - val_accuracy: 0.9152
# Epoch 44/100
# 625/625 - 8s - loss: 0.1441 - accuracy: 0.9512 - val_loss: 0.2861 - val_accuracy: 0.9165
# Epoch 45/100
# 625/625 - 8s - loss: 0.1450 - accuracy: 0.9511 - val_loss: 0.2886 - val_accuracy: 0.9148
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 46/100
# 625/625 - 8s - loss: 0.1367 - accuracy: 0.9525 - val_loss: 0.2863 - val_accuracy: 0.9176
# Epoch 47/100
# 625/625 - 8s - loss: 0.1329 - accuracy: 0.9554 - val_loss: 0.2854 - val_accuracy: 0.9165
# Epoch 48/100
# 625/625 - 8s - loss: 0.1369 - accuracy: 0.9535 - val_loss: 0.2828 - val_accuracy: 0.9178
# Epoch 49/100
# 625/625 - 8s - loss: 0.1329 - accuracy: 0.9539 - val_loss: 0.2851 - val_accuracy: 0.9172
# Epoch 50/100
# 625/625 - 8s - loss: 0.1250 - accuracy: 0.9579 - val_loss: 0.2871 - val_accuracy: 0.9170
# Epoch 51/100
# 625/625 - 8s - loss: 0.1291 - accuracy: 0.9555 - val_loss: 0.2848 - val_accuracy: 0.9171
# Epoch 52/100
# 625/625 - 8s - loss: 0.1307 - accuracy: 0.9542 - val_loss: 0.2889 - val_accuracy: 0.9150
# Epoch 53/100
# 625/625 - 8s - loss: 0.1259 - accuracy: 0.9575 - val_loss: 0.2883 - val_accuracy: 0.9156
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 54/100
# 625/625 - 8s - loss: 0.1243 - accuracy: 0.9568 - val_loss: 0.2856 - val_accuracy: 0.9163
# Epoch 55/100
# 625/625 - 8s - loss: 0.1218 - accuracy: 0.9579 - val_loss: 0.2852 - val_accuracy: 0.9169
# Epoch 56/100
# 625/625 - 8s - loss: 0.1238 - accuracy: 0.9574 - val_loss: 0.2869 - val_accuracy: 0.9159
# Epoch 57/100
# 625/625 - 8s - loss: 0.1185 - accuracy: 0.9598 - val_loss: 0.2849 - val_accuracy: 0.9174
# Epoch 58/100
# 625/625 - 8s - loss: 0.1212 - accuracy: 0.9590 - val_loss: 0.2837 - val_accuracy: 0.9160
# Restoring model weights from the end of the best epoch.
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 00058: early stopping
# CPU times: user 2min 37s, sys: 27.3 s, total: 3min 4s
# Wall time: 8min 1s

# %% [markdown]
# Plot history

# %%
def plot_history(history):
    # plot accuracy
    plt.figure(figsize=(10,5))
    plt.plot(history.history['accuracy'], marker='.', label='acc')
    plt.plot(history.history['val_accuracy'], marker='.', label='val_acc')
    plt.title('model accuracy')
    plt.grid()
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(loc='best')
    plt.show()

    # plot loss
    plt.figure(figsize=(10,5))
    plt.plot(history.history['loss'], marker='.', label='loss')
    plt.plot(history.history['val_loss'], marker='.', label='val_loss')
    plt.title('model loss')
    plt.grid()
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(loc='best')
    plt.show()

plot_history(history)

# %% [markdown]
# # Analyze validation results

# %%
with strategy.scope():
    model = load_model(os.path.join(work_dir, model_file_name))
    model.compile(loss="categorical_crossentropy", optimizer=Adam(), metrics=["accuracy"])

# %%
def calculate_loss_and_acc(y_test, y_pred):
    loss = np.average(categorical_crossentropy(y_test, y_pred))
    if len(y_test.shape) == 2:
        y_test = np.argmax(y_test, axis=1)
    if len(y_pred.shape) == 2:
        y_pred = np.argmax(y_pred, axis=1)
    acc = np.average(np.equal(y_test, y_pred))
    print('loss:', loss, 'acc:', acc)


def show_mistaken_images(X_test, y_test, y_pred, classes):
    miss_X = []
    miss_y_test = []
    miss_y_pred = []
    for i in range(y_test.shape[0]):
        if np.argmax(y_test[i]) != np.argmax(y_pred[i]):
            miss_X.append(X_test[i])
            miss_y_test.append(y_test[i])
            miss_y_pred.append(y_pred[i])
            if len(miss_X) == 10:
                break
    miss_X = np.array(miss_X)
    miss_y_test = np.array(miss_y_test)
    miss_y_pred = np.array(miss_y_pred)
    show_images(miss_X, miss_y_test, miss_y_pred, classes)


def plot_confusion_matrix(y_test, y_pred, classes):
    if len(y_test.shape) == 2:
        y_test = np.argmax(y_test, axis=1)
    if len(y_pred.shape) == 2:
        y_pred = np.argmax(y_pred, axis=1)

    cmx = confusion_matrix(y_test, y_pred)
    vmax = np.sort(np.ravel(cmx))[-len(classes)-1]
    cmx = pd.DataFrame(cmx, index=classes, columns=classes)

    plt.figure(figsize=(10,10))
    sns.heatmap(cmx, vmax=vmax, annot=True, square=True, cmap='Blues')
    plt.xlabel('prediction class')
    plt.ylabel('answer class')
    plt.title('confusion matrix')
    plt.show()

# %%
# %%time
print('validation results')
y_pred = model.predict(X_valid)
calculate_loss_and_acc(y_valid, y_pred)
show_mistaken_images(X_valid, y_valid, y_pred, classes)
plot_confusion_matrix(y_valid, y_pred, classes)
# Out:
# validation results
# loss: 0.2818947 acc: 0.9174
# CPU times: user 2.87 s, sys: 393 ms, total: 3.26 s
# Wall time: 6.92 s

# %% [markdown]
# # Calculate test loss and accuracy

# %%
print('test results')
y_pred = model.predict(X_test)
calculate_loss_and_acc(y_test, y_pred)
# Out:
# test results
# loss: 0.30228242 acc: 0.9141
