# %% [markdown]
# # Fashion-MNIST \~\~\~My Best Version\~\~\~
# This is a notebook which classified Fashion-MNIST by using google colaboratory.<br>
# Test accuracy was 95.30%.<br>
# ## Summary
# * Accelerator: GPU
# * Data Augmentation: Affine Transformation, Random Erasing
# * Model: ResidualBlock x3 - GAP - Dropout - Dense - Dropout - Dense
# * Training: epochs<=200, batch_size=64, optimizer=Adam, Reduce Learning Rate
# * Test Time Augmentation: epochs=20

# %% [markdown]
# Mount My Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

work_dir = "/content/drive/My Drive/Colab Notebooks/fashion_mnist/"
# Out:
# Mounted at /content/drive

# %% [markdown]
# Import modules

# %%
# !pip install visualkeras
from visualkeras import layered_view
# Out:
# Collecting visualkeras
#   Downloading https://files.pythonhosted.org/packages/3c/7d/86ba86f710378e753ed690048710bf917b9121b7c6c5f5b07ec5323c4adc/visualkeras-0.0.1-py3-none-any.whl
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.6/dist-packages (from visualkeras) (7.0.0)
# Installing collected packages: visualkeras
# Successfully installed visualkeras-0.0.1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import os
import cv2

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from collections import Counter, defaultdict

import tensorflow as tf
from tensorflow import keras
from keras.layers import *
from keras.models import Model, load_model
from keras.optimizers import Adam
from keras.utils import plot_model
#from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.losses import categorical_crossentropy

print('tensorflow varsion:', tf.__version__)
print(tf.test.gpu_device_name())
# Out:
# tensorflow varsion: 2.4.1
# /device:GPU:0

# %% [markdown]
# # Load and check data

# %% [markdown]
# Load data

# %%
classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
len(classes)
# Out:
# 10

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# Check data

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
np.min(X_train), np.max(X_train), np.min(X_test), np.max(X_test)
# Out:
# (0, 255, 0, 255)

# %%
def plot_count(y, classes=None, title='y count'):
    plt.figure(figsize=(10,5))
    counter_y = [(key, value) for key, value in Counter(y).items()]
    counter_y.sort(key=lambda x: x[0])
    if classes is None:
        classes = [key for key, value in counter_y]
    values = [value for key, value in counter_y]
    plt.bar(classes, values)
    plt.xlabel('classes')
    plt.ylabel('count')
    plt.title(title)
    plt.show()

plot_count(y_train, classes, title='y_train count')
plot_count(y_test, classes, title='y_test count')

# %%
# show 10 images
def show_images(X, y_true=np.zeros(10), y_pred=None, classes=defaultdict(str)):
    plt.figure(figsize=(10,5))
    for i in range(min(10, X.shape[0], y_true.shape[0])):
        plt.subplot(2,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)

        # plot image
        try:
            plt.imshow(X[i], cmap=plt.cm.binary)
        except:
            plt.imshow(np.reshape(X[i],(X.shape[1],X.shape[2])), cmap=plt.cm.binary)

        # show y_true
        label = ''
        if len(y_true.shape) == 1:
            label += classes[y_true[i]]
        elif len(y_true.shape) == 2:
            label_rate = np.argsort(y_true[i])[::-1]
            if y_true[i][label_rate[0]] > 0.99:
                label = classes[label_rate[0]]
            else:
                label += classes[label_rate[0]] + ': ' + f'{y_true[i][label_rate[0]]:.2f}'
                label += '\n' + classes[label_rate[1]]+': ' + f'{y_true[i][label_rate[1]]:.2f}'
                
        # show y_pred
        if y_pred is None:
            plt.xlabel(label)
            continue

        plt.ylabel('Answer: ' + label)
        label = 'Prediction\n'
        if len(y_pred.shape) == 1:
            label += classes[y_pred[i]]
        elif len(y_pred.shape) == 2:
            label_rate = np.argsort(y_pred[i])[::-1]
            label += classes[label_rate[0]] + ': ' + f'{y_pred[i][label_rate[0]]:.2f}'
            if y_pred[i][label_rate[1]] > 0.01:
                label += '\n' + classes[label_rate[1]]+': ' + f'{y_pred[i][label_rate[1]]:.2f}'
        plt.xlabel(label)

    plt.show()

# %%
show_images(X_train, y_train, classes=classes)

# %% [markdown]
# # Preprocess data

# %% [markdown]
# Normalize images

# %%
X_train = X_train / 255
X_test = X_test / 255

np.min(X_train), np.max(X_train), np.min(X_test), np.max(X_test)
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# Change shapes

# %%
X_train = np.expand_dims(X_train, -1)
X_test = np.expand_dims(X_test, -1)

y_train = keras.utils.to_categorical(y_train, len(classes))
y_test = keras.utils.to_categorical(y_test, len(classes))

# %% [markdown]
# train_test_split

# %%
validation_seed = 0
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train, y_train, test_size=0.2, random_state=validation_seed)

print(X_train.shape, X_valid.shape, X_test.shape)
print(y_train.shape, y_valid.shape, y_test.shape)
# Out:
# (48000, 28, 28, 1) (12000, 28, 28, 1) (10000, 28, 28, 1)
# (48000, 10) (12000, 10) (10000, 10)

# %% [markdown]
# # Augment data

# %%
class MyImageDataGenerator:
    def __init__(self, function_on_a_image=None, function_on_two_batches=None):
        self.function_on_a_image = function_on_a_image
        self.function_on_two_batches = function_on_two_batches

    # You can use flow_with_labels when you train a model.
    def flow_with_labels(self, x, y, batch_size=32, shuffle=True):
        assert x.shape[0] == y.shape[0]
        steps = x.shape[0] // batch_size

        # get one batch for mix
        if self.function_on_two_batches is not None:
            prev_X_batch = x[-batch_size:].copy()
            if self.function_on_a_image is not None:
                prev_X_batch = np.array([
                                self.function_on_a_image(img) for img in prev_X_batch])
            prev_y_batch = y[-batch_size:]
        
        # flow
        while True:
            # shuffle
            if shuffle:
                perm = np.random.permutation(x.shape[0])
                x = x[perm]
                y = y[perm]
            
            # augment images
            for step in range(steps):
                X_batch = x[step*batch_size:(step+1)*batch_size].copy()
                y_batch = y[step*batch_size:(step+1)*batch_size].copy()
                if self.function_on_a_image is not None:
                    X_batch = np.array([self.function_on_a_image(img) for img in X_batch])
                if self.function_on_two_batches is not None:
                    X_batch, y_batch, prev_X_batch, prev_y_batch =\
                        self.function_on_two_batches(
                        prev_X_batch, prev_y_batch, X_batch, y_batch)
                yield X_batch, y_batch
    
    # You can use flow_without_labels in test time augmentation.
    def flow_without_labels(self, x, batch_size=100):
        assert x.shape[0] % batch_size == 0
        steps = x.shape[0] // batch_size
        while True:
            for step in range(steps):
                X_batch = x[step*batch_size:(step+1)*batch_size].copy()
                X_batch = np.array([self.function_on_a_image(img) for img in X_batch])
                yield X_batch
            yield None


# functions on a img
def random_erasing(img, p=0.5, s=(0.02,0.4), r=0.33):
    if np.random.rand() > p:
        return img

    mask_value = 0.0#np.random.rand()
    h, w, _ = img.shape

    mask_area = np.random.uniform(s[0],s[1]) * h*w
    mask_aspect_ratio = np.random.uniform(r, 1.0)
    if np.random.rand() < 0.5:
        mask_aspect_ratio = 1 / mask_aspect_ratio

    mask_h = int(np.sqrt(mask_area / mask_aspect_ratio))
    mask_w = int(mask_h * mask_aspect_ratio)
    mask_h = min(h, mask_h)
    mask_w = min(w, mask_w)

    top = np.random.randint(0,h-mask_h+1)
    left = np.random.randint(0,w-mask_w+1)

    img[top:top+mask_h, left:left+mask_w, :].fill(mask_value)
    return img


def affine_transformation(img):
    ### arguments
    flags = cv2.INTER_LINEAR#cv2.INTER_NEAREST#
    borderMode = cv2.BORDER_CONSTANT#cv2.BORDER_REPLICATE#

    rotate_and_zoom_rate = 0.5#0.0#
    rotate_angle = (-2.5, 2.5)#(-0.0,0.0)#
    scale_range = (0.75, 1.25)#(1.0,1.0)#

    parallel_translation_rate = 0.75#0.0#
    width_shift_range = 0.1#0.2#
    height_shift_range = 0.1#0.2#

    horizontal_flip_rate = 0.3#0.0#
    vertical_flip_rate = 0.0#0.5#
    rotate_90_rate = 0.0#0.5#      
    ###
    height = img.shape[0]
    width = img.shape[1]
    center = (height//2, width//2)

    # rotate and zoom
    if 0.0 < rotate_and_zoom_rate and np.random.rand() < rotate_and_zoom_rate:
        angle = np.random.uniform(rotate_angle[0], rotate_angle[1])
        scale = np.random.uniform(scale_range[0], scale_range[1])
        mat = cv2.getRotationMatrix2D(center, angle, scale)
        img = cv2.warpAffine(img, mat, (width, height),
                             flags=flags, borderMode=borderMode)

    # parallel translation
    if 0.0 < parallel_translation_rate and np.random.rand() < parallel_translation_rate:
        width_shift = int(width*width_shift_range)
        height_shift = int(height*height_shift_range)
        dx = np.random.randint(-width_shift, width_shift+1)
        dy = np.random.randint(-height_shift, height_shift+1)
        src_pts = np.array([[0,0], [0,height], [width, 0]], dtype=np.float32)
        dst_pts = np.array([[dx,dy], [dx,height+dy], [width+dx,dy]], dtype=np.float32)
        mat = cv2.getAffineTransform(src_pts, dst_pts)
        img = cv2.warpAffine(img, mat, (width, height),
                             flags=flags, borderMode=borderMode)
    
    # horizontal flip
    if 0.0 < horizontal_flip_rate and np.random.rand() < horizontal_flip_rate:
        img = cv2.flip(img, 1)

    # vertical flip
    if 0.0 < vertical_flip_rate and np.random.rand() < vertical_flip_rate:
        img = cv2.flip(img, 0)
    
    # rotate 90 degrees
    if 0.0 < rotate_90_rate and np.random.rand() < rotate_90_rate:
        if np.random.rand() < 0.5:
            img = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
        else:
            img = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)

    if len(img.shape) == 2:
        img = np.expand_dims(img, -1)
    
    return img


def gamma_correction(img, intensity=(0.5, 1.5)):
    gamma = np.random.uniform(intensity[0], intensity[1])
    return img ** gamma

# %%
def my_function_on_a_image(img):
    img = affine_transformation(img)
    img = gamma_correction(img)
    img = random_erasing(img)
    return img

datagen = MyImageDataGenerator(my_function_on_a_image)

# %%
print('Before Augmentation')
show_images(X_train, y_train, classes=classes)
# Out:
# Before Augmentation

# %%
print('After Augmentation')
for X_aug, y_aug in datagen.flow_with_labels(X_train, y_train, 10, shuffle=False):
    show_images(X_aug, y_aug, classes=classes)
    break
# Out:
# After Augmentation

# %%
# %%timeit -r 5
def measure_time(datagen_flow, steps):
    cnt = 0
    for X_aug, y_aug in datagen_flow:
        cnt += 1
        if cnt == steps:
            break

measure_time(datagen.flow_with_labels(X_train, y_train, batch_size=64),
             X_train.shape[0]//64)
# Out:
# 1 loop, best of 5: 4.47 s per loop

# %% [markdown]
# # Create model

# %%
def create_model(input_shape, len_classes):
    inputs = Input(input_shape)

    x = Conv2D(32, (3,3), activation='relu')(inputs)
    block_1_output = BatchNormalization()(x)

    x = Conv2D(32, (3,3), activation='relu', padding='same')(block_1_output)
    x = BatchNormalization()(x)
    x = Conv2D(32, (3,3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = add([x, block_1_output])
    x = Conv2D(64, (3,3), activation='relu')(x)
    x = MaxPooling2D(pool_size=(2,2))(x)
    block_2_output = BatchNormalization()(x)

    x = Conv2D(64, (3,3), activation='relu', padding='same')(block_2_output)
    x = BatchNormalization()(x)
    x = Conv2D(64, (3,3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = add([x, block_2_output])
    x = Conv2D(128, (3,3), activation='relu', padding='same')(x)
    x = MaxPooling2D(pool_size=(2,2))(x)
    block_3_output = BatchNormalization()(x)

    x = Conv2D(128, (3,3), activation='relu', padding='same')(block_3_output)
    x = BatchNormalization()(x)
    x = Conv2D(128, (3,3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = add([x, block_3_output])

    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.25)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(len_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=x)
    return model

model = create_model(input_shape=X_train[0].shape, len_classes=len(classes))
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 26, 26, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 26, 26, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 26, 26, 32)   9248        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 26, 26, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 26, 26, 32)   9248        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 26, 26, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 26, 26, 32)   0           batch_normalization_2[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 24, 24, 64)   18496       add[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 12, 12, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 12, 12, 64)   256         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 12, 12, 64)   36928       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 12, 12, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 12, 12, 64)   36928       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 12, 12, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 12, 12, 64)   0           batch_normalization_5[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 12, 12, 128)  73856       add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 6, 6, 128)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 6, 6, 128)    512         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 6, 6, 128)    147584      batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 6, 6, 128)    512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 6, 6, 128)    147584      batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 6, 6, 128)    512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 6, 6, 128)    0           batch_normalization_8[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 128)          0           add_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          66048       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           5130        dropout_1[0][0]
# ==================================================================================================
# Total params: 554,058
# Trainable params: 552,714
# Non-trainable params: 1,344
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True)

# %%
layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=965x150 at 0x7F62E77C6748>

# %% [markdown]
# # Train model

# %%
weights_file_name = "best_weights(seed={}).hdf5".format(validation_seed)
model_file_name = "best_model(seed={}).h5".format(validation_seed)

# %%
# %%time

save_weights = ModelCheckpoint(filepath=os.path.join(work_dir, weights_file_name),
                                verbose=0, save_best_only=True, save_weights_only=True,
                                monitor='val_loss', mode='min')

early_stop = EarlyStopping(monitor='val_loss', mode='min',
                                patience=15, restore_best_weights=True, verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', mode='min',
                                factor=0.8, patience=5, verbose=1)

model.compile(loss="categorical_crossentropy", optimizer=Adam(), metrics=["accuracy"])

batch_size = 64
epochs = 200

history = model.fit(datagen.flow_with_labels(X_train, y_train, batch_size),
                    validation_data=(X_valid, y_valid),
                    epochs=epochs,
                    steps_per_epoch=X_train.shape[0]//batch_size,
                    verbose=2,
                    callbacks=[save_weights, early_stop, reduce_lr])

model.save(os.path.join(work_dir, model_file_name))
# Out:
# Epoch 1/200
# 750/750 - 18s - loss: 0.7427 - accuracy: 0.7251 - val_loss: 0.4355 - val_accuracy: 0.8442
# Epoch 2/200
# 750/750 - 10s - loss: 0.4961 - accuracy: 0.8165 - val_loss: 0.3256 - val_accuracy: 0.8773
# Epoch 3/200
# 750/750 - 10s - loss: 0.4232 - accuracy: 0.8450 - val_loss: 0.2793 - val_accuracy: 0.8957
# Epoch 4/200
# 750/750 - 10s - loss: 0.3914 - accuracy: 0.8562 - val_loss: 0.2662 - val_accuracy: 0.9046
# Epoch 5/200
# 750/750 - 9s - loss: 0.3685 - accuracy: 0.8663 - val_loss: 0.2456 - val_accuracy: 0.9105
# Epoch 6/200
# 750/750 - 9s - loss: 0.3484 - accuracy: 0.8744 - val_loss: 0.2386 - val_accuracy: 0.9133
# Epoch 7/200
# 750/750 - 9s - loss: 0.3335 - accuracy: 0.8788 - val_loss: 0.2305 - val_accuracy: 0.9126
# Epoch 8/200
# 750/750 - 10s - loss: 0.3238 - accuracy: 0.8833 - val_loss: 0.2459 - val_accuracy: 0.9150
# Epoch 9/200
# 750/750 - 9s - loss: 0.3115 - accuracy: 0.8865 - val_loss: 0.2696 - val_accuracy: 0.8997
# Epoch 10/200
# 750/750 - 10s - loss: 0.3052 - accuracy: 0.8888 - val_loss: 0.2224 - val_accuracy: 0.9198
# Epoch 11/200
# 750/750 - 9s - loss: 0.2930 - accuracy: 0.8925 - val_loss: 0.2175 - val_accuracy: 0.9216
# Epoch 12/200
# 750/750 - 10s - loss: 0.2886 - accuracy: 0.8938 - val_loss: 0.2326 - val_accuracy: 0.9172
# Epoch 13/200
# 750/750 - 10s - loss: 0.2822 - accuracy: 0.8964 - val_loss: 0.1971 - val_accuracy: 0.9266
# Epoch 14/200
# 750/750 - 10s - loss: 0.2798 - accuracy: 0.8978 - val_loss: 0.1827 - val_accuracy: 0.9338
# Epoch 15/200
# 750/750 - 10s - loss: 0.2795 - accuracy: 0.8988 - val_loss: 0.2055 - val_accuracy: 0.9233
# Epoch 16/200
# 750/750 - 10s - loss: 0.2678 - accuracy: 0.9048 - val_loss: 0.1763 - val_accuracy: 0.9343
# Epoch 17/200
# 750/750 - 10s - loss: 0.2672 - accuracy: 0.9035 - val_loss: 0.1943 - val_accuracy: 0.9271
# Epoch 18/200
# 750/750 - 10s - loss: 0.2605 - accuracy: 0.9069 - val_loss: 0.1785 - val_accuracy: 0.9355
# Epoch 19/200
# 750/750 - 10s - loss: 0.2570 - accuracy: 0.9074 - val_loss: 0.1862 - val_accuracy: 0.9319
# Epoch 20/200
# 750/750 - 10s - loss: 0.2513 - accuracy: 0.9086 - val_loss: 0.1777 - val_accuracy: 0.9367
# Epoch 21/200
# 750/750 - 10s - loss: 0.2519 - accuracy: 0.9084 - val_loss: 0.1886 - val_accuracy: 0.9329
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 22/200
# 750/750 - 10s - loss: 0.2343 - accuracy: 0.9156 - val_loss: 0.1666 - val_accuracy: 0.9377
# Epoch 23/200
# 750/750 - 10s - loss: 0.2355 - accuracy: 0.9152 - val_loss: 0.1735 - val_accuracy: 0.9360
# Epoch 24/200
# 750/750 - 10s - loss: 0.2285 - accuracy: 0.9177 - val_loss: 0.1558 - val_accuracy: 0.9418
# Epoch 25/200
# 750/750 - 10s - loss: 0.2278 - accuracy: 0.9186 - val_loss: 0.1600 - val_accuracy: 0.9419
# Epoch 26/200
# 750/750 - 10s - loss: 0.2259 - accuracy: 0.9187 - val_loss: 0.1566 - val_accuracy: 0.9411
# Epoch 27/200
# 750/750 - 10s - loss: 0.2225 - accuracy: 0.9186 - val_loss: 0.1645 - val_accuracy: 0.9408
# Epoch 28/200
# 750/750 - 9s - loss: 0.2236 - accuracy: 0.9180 - val_loss: 0.1624 - val_accuracy: 0.9391
# Epoch 29/200
# 750/750 - 10s - loss: 0.2214 - accuracy: 0.9189 - val_loss: 0.1753 - val_accuracy: 0.9377
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# Epoch 30/200
# 750/750 - 9s - loss: 0.2065 - accuracy: 0.9257 - val_loss: 0.1612 - val_accuracy: 0.9423
# Epoch 31/200
# 750/750 - 10s - loss: 0.2099 - accuracy: 0.9235 - val_loss: 0.1526 - val_accuracy: 0.9438
# Epoch 32/200
# 750/750 - 10s - loss: 0.2050 - accuracy: 0.9258 - val_loss: 0.1529 - val_accuracy: 0.9443
# Epoch 33/200
# 750/750 - 9s - loss: 0.2020 - accuracy: 0.9257 - val_loss: 0.1498 - val_accuracy: 0.9490
# Epoch 34/200
# 750/750 - 9s - loss: 0.2002 - accuracy: 0.9268 - val_loss: 0.1510 - val_accuracy: 0.9448
# Epoch 35/200
# 750/750 - 10s - loss: 0.1990 - accuracy: 0.9274 - val_loss: 0.1660 - val_accuracy: 0.9397
# Epoch 36/200
# 750/750 - 10s - loss: 0.1909 - accuracy: 0.9298 - val_loss: 0.1540 - val_accuracy: 0.9442
# Epoch 37/200
# 750/750 - 10s - loss: 0.1946 - accuracy: 0.9294 - val_loss: 0.1454 - val_accuracy: 0.9490
# Epoch 38/200
# 750/750 - 10s - loss: 0.1965 - accuracy: 0.9275 - val_loss: 0.1485 - val_accuracy: 0.9473
# Epoch 39/200
# 750/750 - 10s - loss: 0.1939 - accuracy: 0.9297 - val_loss: 0.1435 - val_accuracy: 0.9498
# Epoch 40/200
# 750/750 - 10s - loss: 0.1909 - accuracy: 0.9295 - val_loss: 0.1479 - val_accuracy: 0.9482
# Epoch 41/200
# 750/750 - 10s - loss: 0.1917 - accuracy: 0.9301 - val_loss: 0.1465 - val_accuracy: 0.9488
# Epoch 42/200
# 750/750 - 10s - loss: 0.1864 - accuracy: 0.9322 - val_loss: 0.1688 - val_accuracy: 0.9390
# Epoch 43/200
# 750/750 - 10s - loss: 0.1902 - accuracy: 0.9312 - val_loss: 0.1498 - val_accuracy: 0.9472
# Epoch 44/200
# 750/750 - 9s - loss: 0.1863 - accuracy: 0.9306 - val_loss: 0.1437 - val_accuracy: 0.9485
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# Epoch 45/200
# 750/750 - 9s - loss: 0.1823 - accuracy: 0.9346 - val_loss: 0.1406 - val_accuracy: 0.9496
# Epoch 46/200
# 750/750 - 10s - loss: 0.1778 - accuracy: 0.9349 - val_loss: 0.1401 - val_accuracy: 0.9502
# Epoch 47/200
# 750/750 - 10s - loss: 0.1769 - accuracy: 0.9350 - val_loss: 0.1422 - val_accuracy: 0.9527
# Epoch 48/200
# 750/750 - 10s - loss: 0.1757 - accuracy: 0.9365 - val_loss: 0.1481 - val_accuracy: 0.9484
# Epoch 49/200
# 750/750 - 10s - loss: 0.1760 - accuracy: 0.9361 - val_loss: 0.1432 - val_accuracy: 0.9486
# Epoch 50/200
# 750/750 - 10s - loss: 0.1759 - accuracy: 0.9353 - val_loss: 0.1387 - val_accuracy: 0.9514
# Epoch 51/200
# 750/750 - 10s - loss: 0.1733 - accuracy: 0.9367 - val_loss: 0.1373 - val_accuracy: 0.9515
# Epoch 52/200
# 750/750 - 10s - loss: 0.1711 - accuracy: 0.9385 - val_loss: 0.1353 - val_accuracy: 0.9532
# Epoch 53/200
# 750/750 - 10s - loss: 0.1721 - accuracy: 0.9376 - val_loss: 0.1392 - val_accuracy: 0.9508
# Epoch 54/200
# 750/750 - 10s - loss: 0.1686 - accuracy: 0.9391 - val_loss: 0.1402 - val_accuracy: 0.9511
# Epoch 55/200
# 750/750 - 10s - loss: 0.1718 - accuracy: 0.9373 - val_loss: 0.1362 - val_accuracy: 0.9507
# Epoch 56/200
# 750/750 - 10s - loss: 0.1657 - accuracy: 0.9392 - val_loss: 0.1432 - val_accuracy: 0.9507
# Epoch 57/200
# 750/750 - 9s - loss: 0.1643 - accuracy: 0.9405 - val_loss: 0.1433 - val_accuracy: 0.9512
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# Epoch 58/200
# 750/750 - 10s - loss: 0.1604 - accuracy: 0.9410 - val_loss: 0.1469 - val_accuracy: 0.9488
# Epoch 59/200
# 750/750 - 10s - loss: 0.1597 - accuracy: 0.9416 - val_loss: 0.1373 - val_accuracy: 0.9525
# Epoch 60/200
# 750/750 - 10s - loss: 0.1590 - accuracy: 0.9418 - val_loss: 0.1375 - val_accuracy: 0.9528
# Epoch 61/200
# 750/750 - 10s - loss: 0.1615 - accuracy: 0.9418 - val_loss: 0.1405 - val_accuracy: 0.9526
# Epoch 62/200
# 750/750 - 10s - loss: 0.1607 - accuracy: 0.9412 - val_loss: 0.1396 - val_accuracy: 0.9514
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# Epoch 63/200
# 750/750 - 10s - loss: 0.1542 - accuracy: 0.9430 - val_loss: 0.1472 - val_accuracy: 0.9506
# Epoch 64/200
# 750/750 - 10s - loss: 0.1553 - accuracy: 0.9437 - val_loss: 0.1336 - val_accuracy: 0.9529
# Epoch 65/200
# 750/750 - 9s - loss: 0.1527 - accuracy: 0.9447 - val_loss: 0.1383 - val_accuracy: 0.9530
# Epoch 66/200
# 750/750 - 10s - loss: 0.1515 - accuracy: 0.9437 - val_loss: 0.1388 - val_accuracy: 0.9533
# Epoch 67/200
# 750/750 - 10s - loss: 0.1500 - accuracy: 0.9446 - val_loss: 0.1386 - val_accuracy: 0.9517
# Epoch 68/200
# 750/750 - 10s - loss: 0.1503 - accuracy: 0.9460 - val_loss: 0.1370 - val_accuracy: 0.9532
# Epoch 69/200
# 750/750 - 9s - loss: 0.1487 - accuracy: 0.9459 - val_loss: 0.1431 - val_accuracy: 0.9498
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# Epoch 70/200
# 750/750 - 10s - loss: 0.1449 - accuracy: 0.9469 - val_loss: 0.1392 - val_accuracy: 0.9536
# Epoch 71/200
# 750/750 - 10s - loss: 0.1426 - accuracy: 0.9474 - val_loss: 0.1334 - val_accuracy: 0.9558
# Epoch 72/200
# 750/750 - 10s - loss: 0.1408 - accuracy: 0.9490 - val_loss: 0.1362 - val_accuracy: 0.9548
# Epoch 73/200
# 750/750 - 10s - loss: 0.1443 - accuracy: 0.9465 - val_loss: 0.1363 - val_accuracy: 0.9543
# Epoch 74/200
# 750/750 - 10s - loss: 0.1429 - accuracy: 0.9480 - val_loss: 0.1324 - val_accuracy: 0.9540
# Epoch 75/200
# 750/750 - 10s - loss: 0.1380 - accuracy: 0.9500 - val_loss: 0.1372 - val_accuracy: 0.9548
# Epoch 76/200
# 750/750 - 10s - loss: 0.1395 - accuracy: 0.9495 - val_loss: 0.1333 - val_accuracy: 0.9568
# Epoch 77/200
# 750/750 - 10s - loss: 0.1404 - accuracy: 0.9487 - val_loss: 0.1312 - val_accuracy: 0.9559
# Epoch 78/200
# 750/750 - 10s - loss: 0.1388 - accuracy: 0.9495 - val_loss: 0.1402 - val_accuracy: 0.9534
# Epoch 79/200
# 750/750 - 10s - loss: 0.1400 - accuracy: 0.9490 - val_loss: 0.1340 - val_accuracy: 0.9548
# Epoch 80/200
# 750/750 - 10s - loss: 0.1386 - accuracy: 0.9499 - val_loss: 0.1527 - val_accuracy: 0.9494
# Epoch 81/200
# 750/750 - 10s - loss: 0.1376 - accuracy: 0.9498 - val_loss: 0.1363 - val_accuracy: 0.9554
# Epoch 82/200
# 750/750 - 10s - loss: 0.1383 - accuracy: 0.9494 - val_loss: 0.1340 - val_accuracy: 0.9558
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# Epoch 83/200
# 750/750 - 9s - loss: 0.1353 - accuracy: 0.9499 - val_loss: 0.1356 - val_accuracy: 0.9557
# Epoch 84/200
# 750/750 - 10s - loss: 0.1322 - accuracy: 0.9517 - val_loss: 0.1367 - val_accuracy: 0.9555
# Epoch 85/200
# 750/750 - 10s - loss: 0.1348 - accuracy: 0.9502 - val_loss: 0.1334 - val_accuracy: 0.9562
# Epoch 86/200
# 750/750 - 10s - loss: 0.1332 - accuracy: 0.9519 - val_loss: 0.1337 - val_accuracy: 0.9572
# Epoch 87/200
# 750/750 - 10s - loss: 0.1336 - accuracy: 0.9509 - val_loss: 0.1389 - val_accuracy: 0.9558
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# Epoch 88/200
# 750/750 - 10s - loss: 0.1323 - accuracy: 0.9508 - val_loss: 0.1377 - val_accuracy: 0.9562
# Epoch 89/200
# 750/750 - 10s - loss: 0.1306 - accuracy: 0.9528 - val_loss: 0.1347 - val_accuracy: 0.9570
# Epoch 90/200
# 750/750 - 10s - loss: 0.1312 - accuracy: 0.9522 - val_loss: 0.1361 - val_accuracy: 0.9560
# Epoch 91/200
# 750/750 - 10s - loss: 0.1281 - accuracy: 0.9531 - val_loss: 0.1374 - val_accuracy: 0.9563
# Epoch 92/200
# 750/750 - 9s - loss: 0.1303 - accuracy: 0.9517 - val_loss: 0.1401 - val_accuracy: 0.9557
# Restoring model weights from the end of the best epoch.
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
# Epoch 00092: early stopping
# CPU times: user 22min 45s, sys: 1min 1s, total: 23min 47s
# Wall time: 15min 2s

# %% [markdown]
# Plot history

# %%
def plot_history(history):
    # plot accuracy
    plt.figure(figsize=(10,5))
    plt.plot(history.history['accuracy'], marker='.', label='acc')
    plt.plot(history.history['val_accuracy'], marker='.', label='val_acc')
    plt.title('model accuracy')
    plt.grid()
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.legend(loc='best')
    plt.show()

    # plot loss
    plt.figure(figsize=(10,5))
    plt.plot(history.history['loss'], marker='.', label='loss')
    plt.plot(history.history['val_loss'], marker='.', label='val_loss')
    plt.title('model loss')
    plt.grid()
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(loc='best')
    plt.show()

plot_history(history)

# %% [markdown]
# # Augment validation data

# %%
model = load_model(os.path.join(work_dir, model_file_name))
model.compile(loss="categorical_crossentropy", optimizer=Adam(), metrics=["accuracy"])

# %%
def test_time_augmentation(model, datagen_flow, steps, epochs=10):
    y_pred = model.predict(datagen_flow, steps=steps)
    for _ in range(epochs-1):
        y_pred += model.predict(datagen_flow, steps=steps)
    return y_pred / epochs


def calculate_loss_and_acc(y_test, y_pred):
    loss = np.average(categorical_crossentropy(y_test, y_pred))
    if len(y_test.shape) == 2:
        y_test = np.argmax(y_test, axis=1)
    if len(y_pred.shape) == 2:
        y_pred = np.argmax(y_pred, axis=1)
    acc = np.average(np.equal(y_test, y_pred))
    print('loss:', loss, 'acc:', acc)


def show_mistaken_images(X_test, y_test, y_pred, classes):
    miss_X = []
    miss_y_test = []
    miss_y_pred = []
    for i in range(y_test.shape[0]):
        if np.argmax(y_test[i]) != np.argmax(y_pred[i]):
            miss_X.append(X_test[i])
            miss_y_test.append(y_test[i])
            miss_y_pred.append(y_pred[i])
            if len(miss_X) == 10:
                break
    miss_X = np.array(miss_X)
    miss_y_test = np.array(miss_y_test)
    miss_y_pred = np.array(miss_y_pred)
    show_images(miss_X, miss_y_test, miss_y_pred, classes)


def plot_confusion_matrix(y_test, y_pred, classes):
    if len(y_test.shape) == 2:
        y_test = np.argmax(y_test, axis=1)
    if len(y_pred.shape) == 2:
        y_pred = np.argmax(y_pred, axis=1)

    cmx = confusion_matrix(y_test, y_pred)
    vmax = np.sort(np.ravel(cmx))[-len(classes)-1]
    cmx = pd.DataFrame(cmx, index=classes, columns=classes)

    plt.figure(figsize=(10,10))
    sns.heatmap(cmx, vmax=vmax, annot=True, square=True, cmap='Blues')
    plt.xlabel('prediction class')
    plt.ylabel('answer class')
    plt.title('confusion matrix')
    plt.show()

# %%
def tta_function_on_a_image(img):
    return gamma_correction(affine_transformation(img))

tta_datagen = MyImageDataGenerator(tta_function_on_a_image)

# %%
print('Before Augmentation')
show_images(X_train, y_train, classes=classes)
# Out:
# Before Augmentation

# %%
print('After Augmentation')
for X_aug in tta_datagen.flow_without_labels(X_train[:10], batch_size=10):
    show_images(X_aug, y_train[:10], classes=classes)
    break
# Out:
# After Augmentation

# %%
# %%time

print('validation results')

print('\nwithout TTA')
loss, acc = model.evaluate(X_valid, y_valid, verbose=0)
print('loss:', loss, 'acc:', acc)

print('\nwith TTA')
tta_datagen = MyImageDataGenerator(affine_transformation)

batch_size = 100
steps = X_valid.shape[0] // batch_size
assert batch_size * steps == X_valid.shape[0]

datagen_flow = tta_datagen.flow_without_labels(X_valid, batch_size)
y_pred = test_time_augmentation(model, datagen_flow, steps, epochs=20)
calculate_loss_and_acc(y_valid, y_pred)
show_mistaken_images(X_valid, y_valid, y_pred, classes)
plot_confusion_matrix(y_valid, y_pred, classes)
# Out:
# validation results
#
# without TTA
# loss: 0.13122880458831787 acc: 0.9559166431427002
#
# with TTA
# loss: 0.121651635 acc: 0.9574166666666667
# CPU times: user 20.7 s, sys: 761 ms, total: 21.5 s
# Wall time: 17.1 s

# %% [markdown]
# # Calculate test loss and accuracy

# %%
print('test results')

batch_size = 100
steps = X_test.shape[0] // batch_size
assert batch_size * steps == X_test.shape[0]

datagen_flow = tta_datagen.flow_without_labels(X_test, batch_size)
y_pred = test_time_augmentation(model, datagen_flow, steps, epochs=20)
calculate_loss_and_acc(y_test, y_pred)
# Out:
# test results
# loss: 0.1364109 acc: 0.953
